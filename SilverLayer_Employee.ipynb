# %%
from pyspark.sql import functions as f
from pyspark.sql import functions as like

# %%
from pyspark.sql.functions import concat_ws

# %%
Employee_df=spark.read.parquet("/Bronze_Layer/Employeefile")

Employee_Contact=Employee_df.withColumn("CONTACT",f.when(Employee_df.EMP_FIRST_NAME=="Fname1","899877765612").otherwise(Employee_df.CONTACT))
#Employee_Contact=New_Column_df.withColumn("CONTACT",f.when(New_Column_df.EMP_FIRST_NAME=="Fname1","899877765612").otherwise(New_Column_df.CONTACT)) #...Kept INAVALID Data

from pyspark.sql.functions import when,length,col,lit

#Condition Check For Contact.......................
Employee_Contact1=Employee_Contact.withColumn("Audit_Contact_no",when(length(col("CONTACT"))==10,"Correct")                           
                          .otherwise("INVALID_Conatct_NUMBER"))

#Put Null Value .....................
#EmployeeName=Employee_Contact1.withColumn("EMP_FIRST_NAME",f.when(Employee_Contact1.EMP_FIRST_NAME=="Fname4",None).otherwise(Employee_Contact1.EMP_FIRST_NAME))

EmployeeName=Employee_Contact.withColumn("EMP_FIRST_NAME",f.when(Employee_Contact.EMP_FIRST_NAME=="Fname4",None).otherwise(Employee_Contact.EMP_FIRST_NAME))

#Condition Check For Name
EmployeeName_Null_df=EmployeeName.withColumn('Employee_Name',when(EmployeeName.EMP_FIRST_NAME.isNull(),"Invalid_Name").otherwise("Correct"))

# %%
#display(Employee_df)
#display(Employee_Contact)
#display(EmployeeName)
#display(Employee_Contact1)
#display(EmployeeName_Null_df)

# %%
p_new=spark.read.parquet("/FileStore/Project/DQFiles/New_File")
display(p_new)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
p_new.write.format("delta").mode("overwrite").saveAsTable("Project_Silver_Layer")

# %%
Emp1=spark.table("Project_Silver_Layer")
display(Emp1)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#display(EmployeeName)
#display(EmployeeName_Null_df1)

# %%
EmployeeFile=EmployeeName_Null_df1.write.mode("overwrite").parquet("/Silver_Layer/EmployeeFile")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <command-2244889194737758> in <module>
# ----> 1 EmployeeFile=EmployeeName_Null_df1.write.mode("overwrite").parquet("/Silver_Layer/EmployeeFile")
#
# NameError: name 'EmployeeName_Null_df1' is not defined

# %%
EF=spark.read.parquet("/Silver_Layer/EmployeeFile")
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# <command-2244889194737760> in <module>
# ----> 1 EF=spark.read.parquet("/Silver_Layer/EmployeeFile")
#
# /databricks/spark/python/pyspark/sql/readwriter.py in parquet(self, *paths, **options)
#     483                        int96RebaseMode=int96RebaseMode)
#     484
# --> 485         return self._df(self._jreader.parquet(_to_seq(self._spark._sc, paths)))
#     486
#     487     def text(self, paths, wholetext=False, lineSep=None, pathGlobFilter=None,
#
# /databricks/spark/python/lib/py4j-0.10.9-src.zip/py4j/java_gateway.py in __call__(self, *args)
#    1302
#    1303         answer = self.gateway_client.send_command(command)
# -> 1304         return_value = get_return_value(
#    1305             answer, self.gateway_client, self.target_id, self.name)
#    1306
#
# /databricks/spark/python/pyspark/sql/utils.py in deco(*a, **kw)
# ...

# %% [markdown]
# # Enter Some Null Values

# %%
Contact_df=Employee_df.withColumn("CONTACT",f.when(Employee_df.EMP_FIRST_NAME=="Fname1",99222904592).otherwise(Employee_df.CONTACT))

Name_df=Contact_df.withColumn("EMP_FIRST_NAME",f.when(Contact_df.EMP_FIRST_NAME=="Fname4",None).otherwise(Contact_df.EMP_FIRST_NAME))

# %%
display(Name_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
Without_Null_record=Name_df.na.drop()
display(Without_Null_record)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
Check=Name_df.filter((Name_df.CONTACT.isNull()) | (Name_df.EMP_FIRST_NAME.isNull()))
display(Check)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
Check=Name_df.filter(Name_df.CONTACT.isNull()) 
display(Check)
                     
                     
Check1=Name_df.filter(Name_df.EMP_FIRST_NAME.isNull())
display(Check1)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>EMP_FIRST_NAME</th><th>EMP_LAST_NAME</th><th>EMP_MIDDLE_NAME</th><th>JOINING_DATE</th><th>LOCATION</th><th>BILLABLE</th><th>IS_ACTV</th><th>LAST_WORKING_DATE</th><th>ADDRESS_LINE_1</th><th>ADDRESS_LINE_2</th><th>ADDRESS_LINE_3</th><th>ADDRESS_LINE_4</th><th>CITY</th><th>STATE</th><th>COUNTRY</th><th>ZIP</th><th>CONTACT</th><th>DEPTNAME</th><th>SUBDEPT_NAME</th><th>ACCOUNT_NUMBER</th><th>BANK_NAME</th><th>SALARY</th><th>DESIGNATION</th></tr></thead><tbody></tbody></table></div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
# ...

# %%
#d=Check.join(Check1,Check.LOCATION ==  Check1.LOCATION,"left").show(truncate=False)

# %%
from pyspark.sql.functions import monotonically_increasing_id
Che = Check.withColumn("row_id", monotonically_increasing_id())
display(Che)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>EMP_FIRST_NAME</th><th>EMP_LAST_NAME</th><th>EMP_MIDDLE_NAME</th><th>JOINING_DATE</th><th>LOCATION</th><th>BILLABLE</th><th>IS_ACTV</th><th>LAST_WORKING_DATE</th><th>ADDRESS_LINE_1</th><th>ADDRESS_LINE_2</th><th>ADDRESS_LINE_3</th><th>ADDRESS_LINE_4</th><th>CITY</th><th>STATE</th><th>COUNTRY</th><th>ZIP</th><th>CONTACT</th><th>DEPTNAME</th><th>SUBDEPT_NAME</th><th>ACCOUNT_NUMBER</th><th>BANK_NAME</th><th>SALARY</th><th>DESIGNATION</th><th>row_id</th></tr></thead><tbody></tbody></table></div>

# %%
Null_record=Name_df.withColumn("Record_Drop_Reason",when(Name_df.EMP_FIRST_NAME.isNull(),"Incorrect_Name").when(Name_df.CONTACT.isNull(),"Incorrect_Cnntact"))
                              
display(Null_record)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#df=spark.read.parquet("/SilverLayer/Employee/Null_Name_Contact")
#display(df)

# %% [markdown]
# # Rejected Records

# %%
Name_df=Name_df.withColumn("Employee_NameNull",f.when(Name_df.EMP_FIRST_NAME.isNull(),"Name_Null").otherwise(" "))
Name_df=Name_df.withColumn("Employee_AddressNull",f.when(Name_df.ADDRESS_LINE_1.isNull() | Name_df.ADDRESS_LINE_2.isNull(),"Address_Null").otherwise(" "))
Name_df=Name_df.withColumn("Incorrect_Contact",f.when((f.length(Name_df.CONTACT)!=10),"Incorrect_Contact_length"))


Name_df=Name_df.select("EMP_FIRST_NAME","EMP_LAST_NAME","EMP_MIDDLE_NAME","JOINING_DATE","LOCATION","BILLABLE","IS_ACTV","LAST_WORKING_DATE","ADDRESS_LINE_1","ADDRESS_LINE_2","ADDRESS_LINE_3","ADDRESS_LINE_4","CITY","STATE","COUNTRY","ZIP","CONTACT","DEPTNAME","SUBDEPT_NAME","ACCOUNT_NUMBER","BANK_NAME","SALARY","DESIGNATION",
                       f.concat_ws('',Name_df.Employee_NameNull,Name_df.Employee_AddressNull,Name_df.Incorrect_Contact).alias("Reason"))


display(Name_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
Name_df=Name_df.filter(~Name_df.Reason.isin('  '))
Emp=Name_df.unionAll(Name_df)

# %%
display(Name_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
Name_df.write.mode("overwrite").parquet("/Rejected_Records/Employee_File")

# %%
Employee=spark.read.parquet("/Rejected_Records/Employee_File")
display(Employee)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
SELECT * FROM Project_Silver_Layer
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
