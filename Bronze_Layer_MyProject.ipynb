# %%
dbutils.fs.mkdirs("/Silver_Layer/")
# Out:
# Out[65]: True

# %%
dbutils.fs.mv("/Silver_Layer","/Bronze_Layer",True)
# Out:
# Out[61]: True

# %%
dbutils.fs.cp("/FileStore/Project/PROJECT_JSON/","Bronze_Layer/ProjectFact",True)
# Out:
# Out[53]: True

# %%
dbutils.fs.rm("/Bronze_Layer/Project_Fact",True)
# Out:
# Out[54]: True

# %% [markdown]
# # parquet Files

# %%
e_df=spark.read.parquet("/Bronze_Layer/Employeefile")

project_df=spark.read.parquet("/Bronze_Layer/ProjectFact")

a_df=spark.read.parquet("/Bronze_Layer/AttendanceFact")

Billing_df=spark.read.parquet("/Bronze_Layer/BillingFact")

# %%
display(e_df)
display(project_df)
display(a_df)
display(Billing_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
/Bronze_Layer/AttendanceFact
